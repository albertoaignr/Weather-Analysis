# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 755

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_description = city_weather['weather'][0]['description']
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]      
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Current Description": city_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | houston
# Processing Record 2 of Set 1 | ilulissat
# Processing Record 3 of Set 1 | riyadh
# Processing Record 4 of Set 1 | esperance
# Processing Record 5 of Set 1 | yellowknife
# Processing Record 6 of Set 1 | atuona
# Processing Record 7 of Set 1 | sinnar
# Processing Record 8 of Set 1 | korla
# Processing Record 9 of Set 1 | cabo san lucas
# Processing Record 10 of Set 1 | georgetown
# Processing Record 11 of Set 1 | clyde river
# Processing Record 12 of Set 1 | thompson
# Processing Record 13 of Set 1 | bambous virieux
# Processing Record 14 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 1 | ola
# Processing Record 16 of Set 1 | san policarpo
# Processing Record 17 of Set 1 | harper
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | kavieng
# Processing Record 20 of Set 1 | palimbang
# Processing Record 21 of Set 1 | castro
# Processing Record 22 of Set 1 | kavaratti
# Processing Record 23 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 1 | hithadhoo
# Processing Record 25 of Set 1 | new norfolk
# Processing Record 26 of Set 1 | cidreira
# Processing Record 27 of Set 1 | terrak
# Processing Record 28 of Set 1 | westport
# Processing Record 29 of Set 1 | port elizabeth
# Processing Record 30 of Set 1 | port alfred
# Processing Record 31 of Set 1 | mikhaylovka
# Processing Record 32 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 1 | sibirskiy
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | east london
# Processing Record 36 of Set 1 | kahului
# Processing Record 37 of Set 1 | rapid valley
# Processing Record 38 of Set 1 | maba
# Processing Record 39 of Set 1 | seddon
# Processing Record 40 of Set 1 | ushuaia
# Processing Record 41 of Set 1 | omboue
# Processing Record 42 of Set 1 | royan
# Processing Record 43 of Set 1 | ailigandi
# Processing Record 44 of Set 1 | amsterdam
# Processing Record 45 of Set 1 | port hardy
# Processing Record 46 of Set 1 | arlit
# Processing Record 47 of Set 1 | pevek
# Processing Record 48 of Set 1 | bathsheba
# Processing Record 49 of Set 1 | rikitea
# Processing Record 50 of Set 1 | beloha
# Processing Record 1 of Set 2 | bredasdorp
# Processing Record 2 of Set 2 | geraldton
# Processing Record 3 of Set 2 | viedma
# Processing Record 4 of Set 2 | amahai
# Processing Record 5 of Set 2 | lasa
# Processing Record 6 of Set 2 | castro-urdiales
# Processing Record 7 of Set 2 | nouadhibou
# Processing Record 8 of Set 2 | cape town
# Processing Record 9 of Set 2 | banda aceh
# Processing Record 10 of Set 2 | athmallik
# Processing Record 11 of Set 2 | faya
# Processing Record 12 of Set 2 | champerico
# Processing Record 13 of Set 2 | galiwinku
# City not found. Skipping...
# Processing Record 14 of Set 2 | arraial do cabo
# Processing Record 15 of Set 2 | hermanus
# Processing Record 16 of Set 2 | ponta do sol
# Processing Record 17 of Set 2 | fort nelson
# Processing Record 18 of Set 2 | vardo
# Processing Record 19 of Set 2 | victoria
# Processing Record 20 of Set 2 | puerto ayora
# Processing Record 21 of Set 2 | hilo
# Processing Record 22 of Set 2 | saskylakh
# Processing Record 23 of Set 2 | pingliang
# Processing Record 24 of Set 2 | carnarvon
# Processing Record 25 of Set 2 | jamestown
# Processing Record 26 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 2 | sayat
# Processing Record 28 of Set 2 | cabra
# Processing Record 29 of Set 2 | narsaq
# Processing Record 30 of Set 2 | iqaluit
# Processing Record 31 of Set 2 | san patricio
# Processing Record 32 of Set 2 | amursk
# Processing Record 33 of Set 2 | leshukonskoye
# Processing Record 34 of Set 2 | vlore
# Processing Record 35 of Set 2 | albany
# Processing Record 36 of Set 2 | berlevag
# Processing Record 37 of Set 2 | haines junction
# Processing Record 38 of Set 2 | saint george
# Processing Record 39 of Set 2 | lethem
# Processing Record 40 of Set 2 | kapaa
# Processing Record 41 of Set 2 | bethel
# Processing Record 42 of Set 2 | ulladulla
# Processing Record 43 of Set 2 | sinnamary
# Processing Record 44 of Set 2 | manyana
# Processing Record 45 of Set 2 | pisco
# Processing Record 46 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 2 | yicheng
# Processing Record 48 of Set 2 | salekhard
# Processing Record 49 of Set 2 | bengkulu
# Processing Record 50 of Set 2 | mezen
# Processing Record 1 of Set 3 | saint-philippe
# Processing Record 2 of Set 3 | tongchuan
# Processing Record 3 of Set 3 | sumbawa
# City not found. Skipping...
# Processing Record 4 of Set 3 | bogale
# Processing Record 5 of Set 3 | prieska
# Processing Record 6 of Set 3 | zhezkazgan
# Processing Record 7 of Set 3 | vestmannaeyjar
# Processing Record 8 of Set 3 | acari
# Processing Record 9 of Set 3 | iranshahr
# Processing Record 10 of Set 3 | pasighat
# Processing Record 11 of Set 3 | turukhansk
# Processing Record 12 of Set 3 | chapais
# Processing Record 13 of Set 3 | fare
# Processing Record 14 of Set 3 | beyneu
# Processing Record 15 of Set 3 | punta arenas
# Processing Record 16 of Set 3 | codrington
# Processing Record 17 of Set 3 | praya
# Processing Record 18 of Set 3 | meiktila
# Processing Record 19 of Set 3 | roma
# Processing Record 20 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 3 | santarem
# Processing Record 22 of Set 3 | sao joao da barra
# Processing Record 23 of Set 3 | parana
# Processing Record 24 of Set 3 | oudtshoorn
# Processing Record 25 of Set 3 | bluff
# Processing Record 26 of Set 3 | solovetskiy
# City not found. Skipping...
# Processing Record 27 of Set 3 | newark
# Processing Record 28 of Set 3 | malinovskiy
# Processing Record 29 of Set 3 | grahamstown
# Processing Record 30 of Set 3 | kabalo
# Processing Record 31 of Set 3 | tasiilaq
# Processing Record 32 of Set 3 | itupiranga
# Processing Record 33 of Set 3 | qafsah
# City not found. Skipping...
# Processing Record 34 of Set 3 | vaini
# Processing Record 35 of Set 3 | portland
# Processing Record 36 of Set 3 | ust-tsilma
# Processing Record 37 of Set 3 | namtsy
# Processing Record 38 of Set 3 | axim
# Processing Record 39 of Set 3 | tura
# Processing Record 40 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 3 | vao
# Processing Record 43 of Set 3 | leua
# Processing Record 44 of Set 3 | butaritari
# Processing Record 45 of Set 3 | hobart
# Processing Record 46 of Set 3 | buraydah
# Processing Record 47 of Set 3 | talakan
# Processing Record 48 of Set 3 | asau
# Processing Record 49 of Set 3 | farum
# Processing Record 50 of Set 3 | capreol
# Processing Record 1 of Set 4 | wuwei
# Processing Record 2 of Set 4 | bismarck
# Processing Record 3 of Set 4 | semenivka
# Processing Record 4 of Set 4 | gangotri
# City not found. Skipping...
# Processing Record 5 of Set 4 | svetlyy
# Processing Record 6 of Set 4 | kodiak
# Processing Record 7 of Set 4 | imbituva
# Processing Record 8 of Set 4 | cherskiy
# Processing Record 9 of Set 4 | wenatchee
# Processing Record 10 of Set 4 | barrow
# Processing Record 11 of Set 4 | carmen
# Processing Record 12 of Set 4 | nikolskoye
# Processing Record 13 of Set 4 | thinadhoo
# Processing Record 14 of Set 4 | pirapora
# Processing Record 15 of Set 4 | afyonkarahisar
# Processing Record 16 of Set 4 | san cristobal
# Processing Record 17 of Set 4 | neuquen
# Processing Record 18 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 19 of Set 4 | kulu
# Processing Record 20 of Set 4 | shingu
# Processing Record 21 of Set 4 | ekhabi
# Processing Record 22 of Set 4 | tondano
# Processing Record 23 of Set 4 | severo-kurilsk
# Processing Record 24 of Set 4 | mar del plata
# Processing Record 25 of Set 4 | krasnoselkup
# Processing Record 26 of Set 4 | dubai
# Processing Record 27 of Set 4 | canyon
# Processing Record 28 of Set 4 | saint anthony
# Processing Record 29 of Set 4 | flinders
# Processing Record 30 of Set 4 | caala
# Processing Record 31 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 4 | langham
# Processing Record 33 of Set 4 | nanortalik
# Processing Record 34 of Set 4 | cockburn town
# Processing Record 35 of Set 4 | soe
# Processing Record 36 of Set 4 | provideniya
# Processing Record 37 of Set 4 | sorong
# Processing Record 38 of Set 4 | yeletskiy
# City not found. Skipping...
# Processing Record 39 of Set 4 | superior
# Processing Record 40 of Set 4 | faanui
# Processing Record 41 of Set 4 | isangel
# Processing Record 42 of Set 4 | broome
# Processing Record 43 of Set 4 | krasnomayskiy
# Processing Record 44 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 4 | humaita
# Processing Record 46 of Set 4 | tuktoyaktuk
# Processing Record 47 of Set 4 | tahe
# Processing Record 48 of Set 4 | karauzyak
# City not found. Skipping...
# Processing Record 49 of Set 4 | jibuti
# Processing Record 50 of Set 4 | qaanaaq
# Processing Record 1 of Set 5 | bilovec
# Processing Record 2 of Set 5 | fortuna
# Processing Record 3 of Set 5 | oussouye
# Processing Record 4 of Set 5 | cayenne
# Processing Record 5 of Set 5 | souillac
# Processing Record 6 of Set 5 | kuandian
# Processing Record 7 of Set 5 | diffa
# Processing Record 8 of Set 5 | lazaro cardenas
# Processing Record 9 of Set 5 | balkhash
# Processing Record 10 of Set 5 | lagoa
# Processing Record 11 of Set 5 | pangnirtung
# Processing Record 12 of Set 5 | te anau
# Processing Record 13 of Set 5 | longyearbyen
# Processing Record 14 of Set 5 | dowa
# Processing Record 15 of Set 5 | knysna
# Processing Record 16 of Set 5 | pelym
# Processing Record 17 of Set 5 | mahebourg
# Processing Record 18 of Set 5 | acapulco
# Processing Record 19 of Set 5 | taldan
# Processing Record 20 of Set 5 | shimoda
# Processing Record 21 of Set 5 | vincennes
# Processing Record 22 of Set 5 | bejar
# Processing Record 23 of Set 5 | komsomolskiy
# Processing Record 24 of Set 5 | broken hill
# Processing Record 25 of Set 5 | hirado
# Processing Record 26 of Set 5 | lebu
# Processing Record 27 of Set 5 | okhotsk
# Processing Record 28 of Set 5 | paso de los toros
# Processing Record 29 of Set 5 | kilimatinde
# Processing Record 30 of Set 5 | iquitos
# Processing Record 31 of Set 5 | kiruna
# Processing Record 32 of Set 5 | biak
# Processing Record 33 of Set 5 | nagato
# Processing Record 34 of Set 5 | jinzhou
# Processing Record 35 of Set 5 | bardsir
# Processing Record 36 of Set 5 | norman wells
# Processing Record 37 of Set 5 | baoro
# Processing Record 38 of Set 5 | rawson
# Processing Record 39 of Set 5 | richards bay
# Processing Record 40 of Set 5 | muli
# Processing Record 41 of Set 5 | ugoofaaru
# Processing Record 42 of Set 5 | grenville
# Processing Record 43 of Set 5 | loiza
# Processing Record 44 of Set 5 | beboto
# Processing Record 45 of Set 5 | zhuanghe
# Processing Record 46 of Set 5 | paine
# Processing Record 47 of Set 5 | katsuura
# Processing Record 48 of Set 5 | sabang
# Processing Record 49 of Set 5 | kirakira
# Processing Record 50 of Set 5 | barcelos
# Processing Record 1 of Set 6 | gorahun
# Processing Record 2 of Set 6 | pueblo
# Processing Record 3 of Set 6 | safaga
# Processing Record 4 of Set 6 | mayor pablo lagerenza
# Processing Record 5 of Set 6 | volchanets
# Processing Record 6 of Set 6 | ati
# Processing Record 7 of Set 6 | grand gaube
# Processing Record 8 of Set 6 | lincoln
# Processing Record 9 of Set 6 | inhambane
# Processing Record 10 of Set 6 | vila velha
# Processing Record 11 of Set 6 | donduseni
# Processing Record 12 of Set 6 | pacific grove
# Processing Record 13 of Set 6 | kushima
# Processing Record 14 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 15 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 16 of Set 6 | torit
# Processing Record 17 of Set 6 | dongzhen
# Processing Record 18 of Set 6 | lodwar
# Processing Record 19 of Set 6 | port-gentil
# Processing Record 20 of Set 6 | chokurdakh
# Processing Record 21 of Set 6 | gazanjyk
# Processing Record 22 of Set 6 | olonets
# Processing Record 23 of Set 6 | deshna
# City not found. Skipping...
# Processing Record 24 of Set 6 | sola
# Processing Record 25 of Set 6 | olhao
# Processing Record 26 of Set 6 | da lat
# Processing Record 27 of Set 6 | upernavik
# Processing Record 28 of Set 6 | miyako
# Processing Record 29 of Set 6 | dale
# Processing Record 30 of Set 6 | cancun
# Processing Record 31 of Set 6 | port blair
# Processing Record 32 of Set 6 | olafsvik
# Processing Record 33 of Set 6 | san quintin
# Processing Record 34 of Set 6 | vila franca do campo
# Processing Record 35 of Set 6 | kaitangata
# Processing Record 36 of Set 6 | nema
# Processing Record 37 of Set 6 | mpika
# Processing Record 38 of Set 6 | antalaha
# Processing Record 39 of Set 6 | marrakesh
# Processing Record 40 of Set 6 | port lincoln
# Processing Record 41 of Set 6 | ostrovnoy
# Processing Record 42 of Set 6 | bajo baudo
# City not found. Skipping...
# Processing Record 43 of Set 6 | saldanha
# Processing Record 44 of Set 6 | guerrero negro
# Processing Record 45 of Set 6 | gore
# Processing Record 46 of Set 6 | avarua
# Processing Record 47 of Set 6 | puerto escondido
# Processing Record 48 of Set 6 | rocha
# Processing Record 49 of Set 6 | loandjili
# Processing Record 50 of Set 6 | alice springs
# Processing Record 1 of Set 7 | dikson
# Processing Record 2 of Set 7 | boulder city
# Processing Record 3 of Set 7 | betioky
# Processing Record 4 of Set 7 | margate
# Processing Record 5 of Set 7 | maniitsoq
# Processing Record 6 of Set 7 | kawhia
# Processing Record 7 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 9 of Set 7 | yongchang
# Processing Record 10 of Set 7 | ballina
# Processing Record 11 of Set 7 | ambon
# Processing Record 12 of Set 7 | east grand rapids
# Processing Record 13 of Set 7 | constitucion
# Processing Record 14 of Set 7 | karpathos
# Processing Record 15 of Set 7 | pundaguitan
# Processing Record 16 of Set 7 | pitimbu
# Processing Record 17 of Set 7 | ustka
# Processing Record 18 of Set 7 | bulolo
# Processing Record 19 of Set 7 | sampit
# Processing Record 20 of Set 7 | karratha
# Processing Record 21 of Set 7 | avera
# Processing Record 22 of Set 7 | hasaki
# Processing Record 23 of Set 7 | tamandare
# Processing Record 24 of Set 7 | los llanos de aridane
# Processing Record 25 of Set 7 | chuy
# Processing Record 26 of Set 7 | mehamn
# Processing Record 27 of Set 7 | khani
# Processing Record 28 of Set 7 | leningradskiy
# Processing Record 29 of Set 7 | boyolangu
# Processing Record 30 of Set 7 | quelimane
# Processing Record 31 of Set 7 | blackfoot
# Processing Record 32 of Set 7 | preobrazheniye
# Processing Record 33 of Set 7 | sept-iles
# Processing Record 34 of Set 7 | kieta
# Processing Record 35 of Set 7 | christchurch
# Processing Record 36 of Set 7 | santa rosa
# Processing Record 37 of Set 7 | sorland
# Processing Record 38 of Set 7 | kushiro
# Processing Record 39 of Set 7 | ribeira grande
# Processing Record 40 of Set 7 | havre-saint-pierre
# Processing Record 41 of Set 7 | katubao
# Processing Record 42 of Set 7 | tuatapere
# Processing Record 43 of Set 7 | sao filipe
# Processing Record 44 of Set 7 | aklavik
# Processing Record 45 of Set 7 | salalah
# Processing Record 46 of Set 7 | atar
# Processing Record 47 of Set 7 | khatanga
# Processing Record 48 of Set 7 | zverinogolovskoye
# Processing Record 49 of Set 7 | palmer
# Processing Record 50 of Set 7 | partyzany
# Processing Record 1 of Set 8 | sitka
# Processing Record 2 of Set 8 | saint-augustin
# Processing Record 3 of Set 8 | darhan
# Processing Record 4 of Set 8 | arifwala
# Processing Record 5 of Set 8 | nova odesa
# Processing Record 6 of Set 8 | rakitovo
# Processing Record 7 of Set 8 | ilhabela
# Processing Record 8 of Set 8 | tawau
# Processing Record 9 of Set 8 | point pedro
# Processing Record 10 of Set 8 | baykit
# Processing Record 11 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 12 of Set 8 | susanville
# Processing Record 13 of Set 8 | tiksi
# Processing Record 14 of Set 8 | lucan
# Processing Record 15 of Set 8 | port hedland
# Processing Record 16 of Set 8 | panguna
# Processing Record 17 of Set 8 | sogdiondon
# City not found. Skipping...
# Processing Record 18 of Set 8 | martapura
# Processing Record 19 of Set 8 | springbok
# Processing Record 20 of Set 8 | tahta
# Processing Record 21 of Set 8 | hambantota
# Processing Record 22 of Set 8 | zachagansk
# City not found. Skipping...
# Processing Record 23 of Set 8 | show low
# Processing Record 24 of Set 8 | caluquembe
# Processing Record 25 of Set 8 | maghama
# City not found. Skipping...
# Processing Record 26 of Set 8 | arenys de mar
# Processing Record 27 of Set 8 | aksarka
# Processing Record 28 of Set 8 | buala
# Processing Record 29 of Set 8 | homer
# Processing Record 30 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 8 | sur
# Processing Record 32 of Set 8 | sovetskiy
# Processing Record 33 of Set 8 | pangai
# Processing Record 34 of Set 8 | alice
# Processing Record 35 of Set 8 | taiyuan
# Processing Record 36 of Set 8 | talnakh
# Processing Record 37 of Set 8 | naryan-mar
# Processing Record 38 of Set 8 | keti bandar
# Processing Record 39 of Set 8 | kibala
# Processing Record 40 of Set 8 | nalut
# Processing Record 41 of Set 8 | huarmey
# Processing Record 42 of Set 8 | novyy urengoy
# Processing Record 43 of Set 8 | kruisfontein
# Processing Record 44 of Set 8 | coquimbo
# Processing Record 45 of Set 8 | manuk mangkaw
# Processing Record 46 of Set 8 | praia da vitoria
# Processing Record 47 of Set 8 | opuwo
# Processing Record 48 of Set 8 | foso
# Processing Record 49 of Set 8 | fairbanks
# Processing Record 50 of Set 8 | aksarayskiy
# Processing Record 1 of Set 9 | nelson bay
# Processing Record 2 of Set 9 | procida
# Processing Record 3 of Set 9 | mongo
# Processing Record 4 of Set 9 | dunedin
# Processing Record 5 of Set 9 | awjilah
# Processing Record 6 of Set 9 | valleyview
# Processing Record 7 of Set 9 | labuhan
# Processing Record 8 of Set 9 | stornoway
# Processing Record 9 of Set 9 | matara
# Processing Record 10 of Set 9 | felipe carrillo puerto
# Processing Record 11 of Set 9 | grand-santi
# Processing Record 12 of Set 9 | gulshat
# City not found. Skipping...
# Processing Record 13 of Set 9 | kununurra
# Processing Record 14 of Set 9 | wanning
# Processing Record 15 of Set 9 | upington
# Processing Record 16 of Set 9 | meulaboh
# Processing Record 17 of Set 9 | ahipara
# Processing Record 18 of Set 9 | gao
# Processing Record 19 of Set 9 | carutapera
# Processing Record 20 of Set 9 | luderitz
# Processing Record 21 of Set 9 | tual
# Processing Record 22 of Set 9 | padang
# Processing Record 23 of Set 9 | santiago del estero
# Processing Record 24 of Set 9 | oranjemund
# Processing Record 25 of Set 9 | khandagayty
# Processing Record 26 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 27 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 28 of Set 9 | autun
# Processing Record 29 of Set 9 | prince rupert
# Processing Record 30 of Set 9 | torbay
# Processing Record 31 of Set 9 | oum hadjer
# Processing Record 32 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 33 of Set 9 | sioux lookout
# Processing Record 34 of Set 9 | emerald
# Processing Record 35 of Set 9 | lukovetskiy
# Processing Record 36 of Set 9 | nurmijarvi
# Processing Record 37 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 9 | noumea
# Processing Record 39 of Set 9 | tutoia
# Processing Record 40 of Set 9 | dangriga
# Processing Record 41 of Set 9 | taguatinga
# Processing Record 42 of Set 9 | lompoc
# Processing Record 43 of Set 9 | kilindoni
# Processing Record 44 of Set 9 | miandrivazo
# Processing Record 45 of Set 9 | kamina
# Processing Record 46 of Set 9 | lobito
# Processing Record 47 of Set 9 | emporia
# Processing Record 48 of Set 9 | chongwe
# Processing Record 49 of Set 9 | erenhot
# Processing Record 50 of Set 9 | kashan
# Processing Record 1 of Set 10 | bemidji
# Processing Record 2 of Set 10 | hanna
# Processing Record 3 of Set 10 | jinchengjiang
# City not found. Skipping...
# Processing Record 4 of Set 10 | alyangula
# Processing Record 5 of Set 10 | ketchikan
# Processing Record 6 of Set 10 | hamilton
# Processing Record 7 of Set 10 | port augusta
# Processing Record 8 of Set 10 | pontianak
# Processing Record 9 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 10 | aras
# Processing Record 11 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 10 | anshun
# Processing Record 13 of Set 10 | missoula
# Processing Record 14 of Set 10 | bichura
# Processing Record 15 of Set 10 | hutchinson
# Processing Record 16 of Set 10 | severnoye
# Processing Record 17 of Set 10 | sosua
# Processing Record 18 of Set 10 | jonkoping
# Processing Record 19 of Set 10 | reinsvoll
# Processing Record 20 of Set 10 | caravelas
# Processing Record 21 of Set 10 | zemio
# Processing Record 22 of Set 10 | tsienyane
# City not found. Skipping...
# Processing Record 23 of Set 10 | lima
# Processing Record 24 of Set 10 | kashira
# Processing Record 25 of Set 10 | jayuya
# Processing Record 26 of Set 10 | nkwerre
# Processing Record 27 of Set 10 | edd
# Processing Record 28 of Set 10 | aktash
# Processing Record 29 of Set 10 | pawa
# Processing Record 30 of Set 10 | at-bashi
# Processing Record 31 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 10 | necochea
# Processing Record 33 of Set 10 | ishigaki
# Processing Record 34 of Set 10 | lakes entrance
# Processing Record 35 of Set 10 | shetpe
# Processing Record 36 of Set 10 | yangambi
# Processing Record 37 of Set 10 | djambala
# Processing Record 38 of Set 10 | vostok
# Processing Record 39 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 40 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 41 of Set 10 | usinsk
# Processing Record 42 of Set 10 | novo aripuana
# Processing Record 43 of Set 10 | itaqui
# Processing Record 44 of Set 10 | jalu
# Processing Record 45 of Set 10 | bilma
# Processing Record 46 of Set 10 | zyryanka
# Processing Record 47 of Set 10 | mucuri
# Processing Record 48 of Set 10 | san jose
# Processing Record 49 of Set 10 | zhitikara
# City not found. Skipping...
# Processing Record 50 of Set 10 | bilibino
# Processing Record 1 of Set 11 | cairns
# Processing Record 2 of Set 11 | kutum
# Processing Record 3 of Set 11 | zeya
# Processing Record 4 of Set 11 | cururupu
# Processing Record 5 of Set 11 | sabla
# Processing Record 6 of Set 11 | noyabrsk
# Processing Record 7 of Set 11 | sao jose do belmonte
# Processing Record 8 of Set 11 | kailua
# Processing Record 9 of Set 11 | kulhudhuffushi
# Processing Record 10 of Set 11 | nicoya
# Processing Record 11 of Set 11 | kaili
# Processing Record 12 of Set 11 | araceli
# Processing Record 13 of Set 11 | kupang
# Processing Record 14 of Set 11 | espanola
# Processing Record 15 of Set 11 | arandis
# Processing Record 16 of Set 11 | waterloo
# Processing Record 17 of Set 11 | lavrentiya
# Processing Record 18 of Set 11 | tiarei
# Processing Record 19 of Set 11 | catabola
# Processing Record 20 of Set 11 | takoradi
# Processing Record 21 of Set 11 | trelew
# Processing Record 22 of Set 11 | beringovskiy
# Processing Record 23 of Set 11 | yanan
# City not found. Skipping...
# Processing Record 24 of Set 11 | salinopolis
# Processing Record 25 of Set 11 | florianopolis
# Processing Record 26 of Set 11 | griffith
# Processing Record 27 of Set 11 | acurenam
# Processing Record 28 of Set 11 | monterey
# Processing Record 29 of Set 11 | geresk
# City not found. Skipping...
# Processing Record 30 of Set 11 | laguna
# Processing Record 31 of Set 11 | dahanu
# Processing Record 32 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 33 of Set 11 | alexandria
# Processing Record 34 of Set 11 | smithers
# Processing Record 35 of Set 11 | maues
# Processing Record 36 of Set 11 | wanxian
# Processing Record 37 of Set 11 | moron
# Processing Record 38 of Set 11 | clovis
# Processing Record 39 of Set 11 | nioki
# Processing Record 40 of Set 11 | ginda
# Processing Record 41 of Set 11 | banyo
# Processing Record 42 of Set 11 | airai
# Processing Record 43 of Set 11 | mashhad
# Processing Record 44 of Set 11 | gornopravdinsk
# Processing Record 45 of Set 11 | killarney
# Processing Record 46 of Set 11 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 11 | ratnagiri
# Processing Record 48 of Set 11 | port-cartier
# Processing Record 49 of Set 11 | pahrump
# Processing Record 50 of Set 11 | urdzhar
# City not found. Skipping...
# Processing Record 1 of Set 12 | duobao
# Processing Record 2 of Set 12 | mount pleasant
# Processing Record 3 of Set 12 | qaqortoq
# Processing Record 4 of Set 12 | la ronge
# Processing Record 5 of Set 12 | goteborg
# City not found. Skipping...
# Processing Record 6 of Set 12 | anadyr
# Processing Record 7 of Set 12 | nha trang
# Processing Record 8 of Set 12 | bonthe
# Processing Record 9 of Set 12 | presidencia roque saenz pena
# Processing Record 10 of Set 12 | ponta pora
# Processing Record 11 of Set 12 | helena
# Processing Record 12 of Set 12 | tonj
# Processing Record 13 of Set 12 | oriximina
# Processing Record 14 of Set 12 | lenine
# Processing Record 15 of Set 12 | havre
# Processing Record 16 of Set 12 | nome
# Processing Record 17 of Set 12 | dharmanagar
# Processing Record 18 of Set 12 | ahuimanu
# Processing Record 19 of Set 12 | fredericksburg
# Processing Record 20 of Set 12 | barroualie
# City not found. Skipping...
# Processing Record 21 of Set 12 | marawi
# Processing Record 22 of Set 12 | rio grande
# Processing Record 23 of Set 12 | gat
# Processing Record 24 of Set 12 | bandarbeyla
# Processing Record 25 of Set 12 | honiara
# Processing Record 26 of Set 12 | virtsu
# Processing Record 27 of Set 12 | sulangan
# Processing Record 28 of Set 12 | rio gallegos
# Processing Record 29 of Set 12 | mount isa
# Processing Record 30 of Set 12 | qasigiannguit
# Processing Record 31 of Set 12 | puerto leguizamo
# Processing Record 32 of Set 12 | majene
# Processing Record 33 of Set 12 | hovd
# Processing Record 34 of Set 12 | klaksvik
# Processing Record 35 of Set 12 | suksun
# Processing Record 36 of Set 12 | auki
# Processing Record 37 of Set 12 | nuevitas
# Processing Record 38 of Set 12 | muisne
# Processing Record 39 of Set 12 | burica
# City not found. Skipping...
# Processing Record 40 of Set 12 | nasrullaganj
# City not found. Skipping...
# Processing Record 41 of Set 12 | alamosa
# Processing Record 42 of Set 12 | flagstaff
# Processing Record 43 of Set 12 | de aar
# Processing Record 44 of Set 12 | lata
# Processing Record 45 of Set 12 | strelka
# Processing Record 46 of Set 12 | saint-joseph
# Processing Record 47 of Set 12 | prado
# Processing Record 48 of Set 12 | cherepanovo
# Processing Record 49 of Set 12 | segezha
# Processing Record 50 of Set 12 | filingue
# Processing Record 1 of Set 13 | evans
# Processing Record 2 of Set 13 | taoudenni
# Processing Record 3 of Set 13 | chaman
# Processing Record 4 of Set 13 | trinidad
# Processing Record 5 of Set 13 | bato
# Processing Record 6 of Set 13 | nyurba
# Processing Record 7 of Set 13 | seoul
# Processing Record 8 of Set 13 | malpe
# Processing Record 9 of Set 13 | north bend
# Processing Record 10 of Set 13 | zhumadian
# Processing Record 11 of Set 13 | puri
# Processing Record 12 of Set 13 | encruzilhada
# Processing Record 13 of Set 13 | talhar
# Processing Record 14 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 15 of Set 13 | san marco in lamis
# Processing Record 16 of Set 13 | santa maria
# Processing Record 17 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 18 of Set 13 | hachinohe
# Processing Record 19 of Set 13 | deputatskiy
# Processing Record 20 of Set 13 | san julian
# Processing Record 21 of Set 13 | kuybyshevo
# Processing Record 22 of Set 13 | tarbes
# Processing Record 23 of Set 13 | shu
# Processing Record 24 of Set 13 | sento se
# City not found. Skipping...
# Processing Record 25 of Set 13 | botou
# Processing Record 26 of Set 13 | kulevcha
# Processing Record 27 of Set 13 | ferkessedougou
# Processing Record 28 of Set 13 | sayyan
# Processing Record 29 of Set 13 | ambulu
# Processing Record 30 of Set 13 | sesheke
# Processing Record 31 of Set 13 | bubaque
# Processing Record 32 of Set 13 | teahupoo
# Processing Record 33 of Set 13 | melbu
# Processing Record 34 of Set 13 | ondo
# Processing Record 35 of Set 13 | werda
# Processing Record 36 of Set 13 | ercis
# Processing Record 37 of Set 13 | hobyo
# Processing Record 38 of Set 13 | hokitika
# Processing Record 39 of Set 13 | tessalit
# Processing Record 40 of Set 13 | anage
# Processing Record 41 of Set 13 | henties bay
# Processing Record 42 of Set 13 | dunstable
# Processing Record 43 of Set 13 | el vigia
# Processing Record 44 of Set 13 | egvekinot
# Processing Record 45 of Set 13 | cortez
# Processing Record 46 of Set 13 | kaeo
# Processing Record 47 of Set 13 | moussoro
# Processing Record 48 of Set 13 | namibe
# Processing Record 49 of Set 13 | north myrtle beach
# Processing Record 50 of Set 13 | maturin
# Processing Record 1 of Set 14 | bacuit
# City not found. Skipping...
# Processing Record 2 of Set 14 | ituni
# City not found. Skipping...
# Processing Record 3 of Set 14 | tanete
# Processing Record 4 of Set 14 | jiamusi
# Processing Record 5 of Set 14 | walvis bay
# Processing Record 6 of Set 14 | evensk
# Processing Record 7 of Set 14 | sambava
# Processing Record 8 of Set 14 | dobric
# Processing Record 9 of Set 14 | tadepallegudem
# Processing Record 10 of Set 14 | pandan
# Processing Record 11 of Set 14 | doctor juan manuel frutos
# Processing Record 12 of Set 14 | nam tha
# City not found. Skipping...
# Processing Record 13 of Set 14 | krasnoborsk
# Processing Record 14 of Set 14 | monte alegre
# Processing Record 15 of Set 14 | san rafael del sur
# Processing Record 16 of Set 14 | paamiut
# Processing Record 17 of Set 14 | ancud
# Processing Record 18 of Set 14 | isla mujeres
# Processing Record 19 of Set 14 | aventura
# Processing Record 20 of Set 14 | zhigansk
# Processing Record 21 of Set 14 | zabol
# Processing Record 22 of Set 14 | yar-sale
# Processing Record 23 of Set 14 | tilichiki
# Processing Record 24 of Set 14 | teguldet
# Processing Record 25 of Set 14 | prabumulih
# Processing Record 26 of Set 14 | naze
# Processing Record 27 of Set 14 | ulaangom
# Processing Record 28 of Set 14 | porrentruy
# Processing Record 29 of Set 14 | nantucket
# Processing Record 30 of Set 14 | birao
# Processing Record 31 of Set 14 | zhanatas
# City not found. Skipping...
# Processing Record 32 of Set 14 | salta
# Processing Record 33 of Set 14 | hami
# Processing Record 34 of Set 14 | poso
# Processing Record 35 of Set 14 | kurilsk
# Processing Record 36 of Set 14 | hay river
# Processing Record 37 of Set 14 | dhidhdhoo
# Processing Record 38 of Set 14 | saint-raphael
# Processing Record 39 of Set 14 | colac
# Processing Record 40 of Set 14 | tommot
# Processing Record 41 of Set 14 | jablanica
# Processing Record 42 of Set 14 | dingle
# Processing Record 43 of Set 14 | cotonou
# Processing Record 44 of Set 14 | ijaki
# City not found. Skipping...
# Processing Record 45 of Set 14 | sal rei
# Processing Record 46 of Set 14 | brattleboro
# Processing Record 47 of Set 14 | puerto madero
# Processing Record 48 of Set 14 | butembo
# Processing Record 49 of Set 14 | muroto
# Processing Record 50 of Set 14 | katobu
# Processing Record 1 of Set 15 | zandvoort
# Processing Record 2 of Set 15 | kimamba
# Processing Record 3 of Set 15 | lorengau
# Processing Record 4 of Set 15 | portel
# Processing Record 5 of Set 15 | greytown
# Processing Record 6 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 7 of Set 15 | raga
# Processing Record 8 of Set 15 | nuuk
# Processing Record 9 of Set 15 | amapa
# Processing Record 10 of Set 15 | oranjestad
# Processing Record 11 of Set 15 | araouane
# Processing Record 12 of Set 15 | fountain hills
# Processing Record 13 of Set 15 | tucuman
# Processing Record 14 of Set 15 | geilo
# Processing Record 15 of Set 15 | port angeles
# Processing Record 16 of Set 15 | novyy chirkey
# Processing Record 17 of Set 15 | vanavara
# Processing Record 18 of Set 15 | repalle
# Processing Record 19 of Set 15 | san vicente
# Processing Record 20 of Set 15 | tagusao
# Processing Record 21 of Set 15 | san pedro
# Processing Record 22 of Set 15 | albacete
# Processing Record 23 of Set 15 | monywa
# Processing Record 24 of Set 15 | chernyshevskiy
# Processing Record 25 of Set 15 | arys
# Processing Record 26 of Set 15 | belen
# Processing Record 27 of Set 15 | garowe
# Processing Record 28 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 29 of Set 15 | foam lake
# Processing Record 30 of Set 15 | sancti spiritus
# Processing Record 31 of Set 15 | midyat
# Processing Record 32 of Set 15 | aswan
# Processing Record 33 of Set 15 | borogontsy
# Processing Record 34 of Set 15 | ucluelet
# Processing Record 35 of Set 15 | sungairaya
# Processing Record 36 of Set 15 | birjand
# Processing Record 37 of Set 15 | gra liyia
# Processing Record 38 of Set 15 | anahuac
# Processing Record 39 of Set 15 | kalengwa
# Processing Record 40 of Set 15 | kloulklubed
# Processing Record 41 of Set 15 | jumla
# Processing Record 42 of Set 15 | vytegra
# Processing Record 43 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 44 of Set 15 | santo augusto
# Processing Record 45 of Set 15 | parkes
# Processing Record 46 of Set 15 | sao gabriel
# Processing Record 47 of Set 15 | taltal
# Processing Record 48 of Set 15 | ponta delgada
# Processing Record 49 of Set 15 | nurota
# Processing Record 50 of Set 15 | konevo
# Processing Record 1 of Set 16 | helmsdale
# Processing Record 2 of Set 16 | cap malheureux
# Processing Record 3 of Set 16 | jiuquan
# Processing Record 4 of Set 16 | galesong
# Processing Record 5 of Set 16 | aqtobe
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 693

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0         Houston  29.7633  -95.3633     58.33           clear sky        49
# 1       Ilulissat  69.2167  -51.1000     26.62     overcast clouds        74
# 2          Riyadh  24.6877   46.7219     78.94           clear sky        28
# 3       Esperance -33.8667  121.9000     55.87     overcast clouds        65
# 4     Yellowknife  62.4560 -114.3525     27.12       broken clouds       100
# 5          Atuona  -9.8000 -139.0333     77.56           clear sky        76
# 6          Sinnar  13.5691   33.5672     83.10          few clouds        25
# 7           Korla  41.7597   86.1469     35.78           clear sky        50
# 8  Cabo San Lucas  22.8909 -109.9124     81.18    scattered clouds        64
# 9      Georgetown   5.4112  100.3354     81.23          light rain        90
#
#    Cloudiness  Wind Speed Country
# 0           0        5.99      US
# 1         100        2.30      GL
# 2           0        9.91      SA
# 3         100        7.27      AU
# 4          75        3.44      CA
# 5           2       19.04      PF
# 6          16       10.07      SD
# 7           0        2.86      CN
# 8          43        5.99      MX
# 9          20        0.00      MY

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Houston      US  29.7633  -95.3633     58.33        49           0
# 1       Ilulissat      GL  69.2167  -51.1000     26.62        74         100
# 2          Riyadh      SA  24.6877   46.7219     78.94        28           0
# 3       Esperance      AU -33.8667  121.9000     55.87        65         100
# 4     Yellowknife      CA  62.4560 -114.3525     27.12       100          75
# 5          Atuona      PF  -9.8000 -139.0333     77.56        76           2
# 6          Sinnar      SD  13.5691   33.5672     83.10        25          16
# 7           Korla      CN  41.7597   86.1469     35.78        50           0
# 8  Cabo San Lucas      MX  22.8909 -109.9124     81.18        64          43
# 9      Georgetown      MY   5.4112  100.3354     81.23        90          20
#
#    Wind Speed Current Description
# 0        5.99           clear sky
# 1        2.30     overcast clouds
# 2        9.91           clear sky
# 3        7.27     overcast clouds
# 4        3.44       broken clouds
# 5       19.04           clear sky
# 6       10.07          few clouds
# 7        2.86           clear sky
# 8        5.99    scattered clouds
# 9        0.00          light rain

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
